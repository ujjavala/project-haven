# %% [markdown]
# # Bushfire Prediction
#
# ## Background:
# The Historical Bushfire Boundaries Dataset (version 2) represents the aggregation of jurisdictional supplied burnt areas polygons that date from the early 1900s through to 2023 (excluding the Northern Territory). The burnt areas represent curated jurisdictional owned polygons of bushfires and prescribed (planned) burns.
#
# It has the following features:
#
# fire_id
# fire_name
# ignition_date
# capture_date
# extinguish_date
# fire_type
# ignition_cause
# capt_method
# area_ha
# perim_km
# state
# agency
# Shape__Area
# Shape__Length
#
# ## Steps Involved
# 1. Import the libraries
# 2. Read the data from the csv file
# 3. Cleanse the data
# 4. Removing Outliers
# 5. Defining dependent and independent attributes and splitting
# 6. Prediction through manual fitting and Linear Regression
# 7. Total model accuracy
# 8. Other algorithms
# 8. Elastic model
# 9. XGBoost model
# 10. Compare model results
# 11. Training Xgboost with winning hyperparameters
# 12. Prediction leveraging xgboost
#
# ## Flowchart
# ![flowchart.jpg](attachment:flowchart.jpg)
#
# ## Outcome:
# 1. Data was clean but imputations were required for "hybrid" column and the outliers were dropped.
# 2. On comparison of metrics for two different algorithms, Xgboost has outperformed other two algorithms on all three metrics (RMSE, MAE and R^2).
#
# ### Results from fitting and training
#
# #### Elastic net
#
# Elastic net model for ER with 10-fold CV results in:
# Test rmse of 0.43766 with standard error of 0.00122.
# Test mae of 0.31589 with standard error of 0.00073.
# Test r2 of 0.65404 with standard error of 0.00275.
#
# #### XGBoost
#
# XGBoost model for ER with 10-fold CV results in:
# Test rmse of 0.06597 with standard error of 0.00074.
# Test mae of 0.00791 with standard error of 0.00016.
# Test r2 of 0.99213 with standard error of 0.00018.
#
#
# #### Best sample after using xgboost training
#
# `{'eta': np.float64(0.01031037901918658), 'max_depth': np.int64(18), 'min_child_weight': np.float64(3.0), 'subsample': np.float64(0.5182959940222093)}`
#
#
#
# ## Future Work:
# 1. The Error rate of prediction can be improved, using more data centric approach.
# 2. Model validations, interpretability and diagnostics need to be performed.

# %% [markdown]
# ## Execution Steps

# %% [markdown]
# ### Import the libraries
#
# Prerequeisites:
#
# 1. Make sure that you have python installed
# 1. For the libraries that are not found, simply run `pip install <module_name>`

# %%
# Import

from hyperopt  import hp, fmin, tpe, Trials, STATUS_OK # type: ignore
import numpy as np
import pandas as pd
from functools import partial
import re
import sys

import matplotlib.pyplot as plt # type: ignore
import seaborn as sns # type: ignore

from utils.eda_utils import df_overview
from utils.model_utils import *

pd.set_option("display.max_rows", 150)
pd.set_option("display.max_columns", 500)
np.set_printoptions(precision=4, suppress=True)
pd.set_option("display.width", 100)

# # Modeling needs
# from sklearn.metrics import r2_score 
# from sklearn.model_selection import  train_test_split 
from sklearn.linear_model import LinearRegression

# Modeling needs
from scipy.stats import sem
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import StandardScaler


# Modeling needs 
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb

# %% [markdown]
# ### Read the data from the csv file

# %%
# Read the data

file = (r"Historical_Bushfire_Boundaries.csv")

df = pd.read_csv(file)
df.shape
# Out:
# (311984, 15)

# %%
df.sample(5)
# Out:
#         OBJECTID fire_id                           fire_name           ignition_date capture_date  \
# 248534    248535     NaN  Great Sandy National Park/1976/P/5  1976/01/01 00:00:00+00          NaN
# 213450    213451     999                                      2012/07/01 00:00:00+00          NaN
# 135544    135545     268         Murray Sunset - Walker Road  2019/05/19 00:00:00+00          NaN
# 24690      24691     999                                 NaN  2016/11/05 00:00:00+00          NaN
# 251851    251852     999                                      1939/09/16 00:00:00+00          NaN
#
#        extinguish_date        fire_type ignition_cause         capt_method  area_ha  perim_km  \
# 248534             NaN  Prescribed Burn            NaN                 NaN     2367        28
# 213450             NaN          Unknown            NaN             Landsat        2         1
# 135544             NaN  Prescribed Burn            NaN                 NaN        0         0
# ...

# %%
df.describe()
# Out:
#             OBJECTID       area_ha       perim_km   Shape__Area  Shape__Length
# count  311984.000000  3.119840e+05  311984.000000  3.119840e+05   3.119840e+05
# mean   155992.500000  2.296942e+03      52.401777  1.022608e-03   1.141268e-01
# std     90062.167529  4.620564e+04     837.033427  1.817445e-02   5.491933e-01
# min         1.000000  0.000000e+00       0.000000  0.000000e+00   1.437568e-07
# 25%     77996.750000  1.000000e+00       0.000000  8.348505e-07   4.268383e-03
# 50%    155992.500000  9.000000e+00       2.000000  8.281588e-06   1.618414e-02
# 75%    233988.250000  8.500000e+01       6.000000  8.164109e-05   5.942387e-02
# max    311984.000000  5.763897e+06   47692.000000  3.665107e+00   3.256993e+01

# %%
df_overview(df)
# Out:
#        column_label     type  uniques_values  non_null_values  null_values  null_value_pct
# 0          OBJECTID    int64          311984           311984            0            0.00
# 1           fire_id   object           35318           277309        34675           11.11
# 2         fire_name   object           53165           234544        77440           24.82
# 3     ignition_date   object           13023           295525        16459            5.28
# 4      capture_date   object              56              258       311726           99.92
# 5   extinguish_date   object            8564            28186       283798           90.97
# 6         fire_type   object               3           311983            1            0.00
# 7    ignition_cause   object               6            17986       293998           94.23
# 8       capt_method   object              10           173552       138432           44.37
# ...

# %% [markdown]
# ### Cleanse the data
#
# This can be achieved by:
# 1. Removing null rows
# 2. Dropping irrelevant columns
# 3. Removing rows where significant columns have null values

# %%
# Delete the rows without any data
df_filtered = df.dropna(how='all').copy()
df_filtered = df_filtered[df_filtered['ignition_date'].notna()]


df_filtered = df_filtered.drop(["fire_name","capt_method", "capture_date","extinguish_date","ignition_cause","agency","fire_id"], axis=1)
df_filtered['ignition_month'] = pd.to_datetime(df_filtered['ignition_date']).dt.month
df_filtered['ignition_year'] = pd.to_datetime(df_filtered['ignition_date']).dt.year
df_filtered[df_filtered["fire_type"]=='Bushfire']
# Out:
#         OBJECTID           ignition_date fire_type  area_ha  perim_km                   state  \
# 5              6  2009/12/05 00:00:00+00  Bushfire    22392        91   NSW (New South Wales)
# 9             10  1964/01/01 00:00:00+00  Bushfire        6         1          VIC (Victoria)
# 17            18  2014/03/23 00:00:00+00  Bushfire        1         0  WA (Western Australia)
# 18            19  2012/12/04 00:00:00+00  Bushfire      539        12   NSW (New South Wales)
# 22            23  1994/12/31 00:00:00+00  Bushfire        7         1    SA (South Australia)
# ...          ...                     ...       ...      ...       ...                     ...
# 311977    311978  2021/11/17 00:00:00+00  Bushfire    12511       685  WA (Western Australia)
# 311978    311979  2009/11/16 00:00:00+00  Bushfire    50675      3439  WA (Western Australia)
# 311979    311980  2009/11/16 00:00:00+00  Bushfire    50675      3439  WA (Western Australia)
# ...

# %%
df_overview(df_filtered)
# Out:
#      column_label     type  uniques_values  non_null_values  null_values  null_value_pct
# 0        OBJECTID    int64          295525           295525            0             0.0
# 1   ignition_date   object           13023           295525            0             0.0
# 2       fire_type   object               3           295524            1             0.0
# 3         area_ha    int64           10267           295525            0             0.0
# 4        perim_km    int64            1590           295525            0             0.0
# 5           state   object               7           295525            0             0.0
# 6     Shape__Area  float64          263751           295525            0             0.0
# 7   Shape__Length  float64          294007           295525            0             0.0
# 8  ignition_month    int32              12           295525            0             0.0
# ...

# %%
df_filtered.describe()
# Out:
#             OBJECTID       area_ha       perim_km   Shape__Area  Shape__Length  ignition_month  \
# count  295525.000000  2.955250e+05  295525.000000  2.955250e+05   2.955250e+05   295525.000000
# mean   156085.677560  2.358811e+03      54.807468  1.015214e-03   1.158782e-01        5.736005
# std     90093.397931  4.689238e+04     859.872719  1.708296e-02   5.580353e-01        3.707010
# min         1.000000  0.000000e+00       0.000000  0.000000e+00   1.437568e-07        1.000000
# 25%     78117.000000  1.000000e+00       0.000000  7.543808e-07   4.061542e-03        2.000000
# 50%    156023.000000  8.000000e+00       2.000000  7.634300e-06   1.562001e-02        5.000000
# 75%    234105.000000  8.100000e+01       6.000000  7.733513e-05   5.846122e-02        9.000000
# max    311984.000000  5.763897e+06   47692.000000  3.665107e+00   3.256993e+01       12.000000
#
#        ignition_year
# count  295525.000000
# mean     1999.739545
# std        20.850280
# min      1899.000000
# ...

# %%
df_filtered.sample(5)
# Out:
#         OBJECTID           ignition_date        fire_type  area_ha  perim_km  \
# 240071    240072  2021/04/18 00:00:00+00  Prescribed Burn        0         0
# 152106    152107  1970/09/16 00:00:00+00  Prescribed Burn      331        13
# 248569    248570  1994/01/01 00:00:00+00          Unknown        3         1
# 132848    132849  2020/04/06 00:00:00+00         Bushfire        0         0
# 20818      20819  1969/01/01 00:00:00+00          Unknown        1         0
#
#                          state   Shape__Area  Shape__Length  ignition_month  ignition_year
# 240071          VIC (Victoria)  8.860707e-08       0.002032               4           2021
# 152106  WA (Western Australia)  3.191528e-04       0.128879               9           1970
# 248569  WA (Western Australia)  2.814305e-06       0.010114               1           1994
# 132848  WA (Western Australia)  9.471796e-08       0.001097               4           2020
# ...

# %%
xdata = df_filtered["state"]  # Setting the x values
ydata = df_filtered["area_ha"]  # setting the y values
t = np.arange(295525)

plt.figure(figsize = (20,4)) # set the size of the figure
plt.scatter(xdata, ydata, c=t) # scatter plot of the data
plt.xlabel("State")
plt.ylabel("Area in Hectares")
# Out:
# Text(0, 0.5, 'Area in Hectares')

# %%
xdata = df_filtered["ignition_month"]  # setting the x values
ydata = df_filtered["area_ha"]  # Setting the y values
t = np.arange(295525)

plt.figure(figsize = (12,6)) # set the size of the figure
plt.scatter(xdata, ydata, c=t) # scatter plot of the data
plt.xlabel("Ignition Month")
plt.ylabel("Area in Hectares")
# Out:
# Text(0, 0.5, 'Area in Hectares')

# %%
xdata = df_filtered["ignition_year"]  # setting the x values
ydata = df_filtered["area_ha"]  # Setting the y values
t = np.arange(295525)

plt.figure(figsize = (20,6)) # set the size of the figure
plt.scatter(xdata, ydata, c=t) # scatter plot of the data
plt.xlabel("Ignition Year")
plt.ylabel("Area in Hectares")
# Out:
# Text(0, 0.5, 'Area in Hectares')

# %% [markdown]
# ### Removing Outliers

# %%
# Remove rows pre-1970 (sparse/unreliable data)
df_filtered = df_filtered[df_filtered["ignition_year"] > 1970].copy()

# Log-transform area_ha then use IQR to remove extreme outliers
# (the old `area_ha < 3` filter was backwards — it kept only tiny fires,
#  discarding the large, dangerous ones we actually care about)
log_area = np.log1p(df_filtered["area_ha"])
q1, q3 = log_area.quantile(0.01), log_area.quantile(0.99)
df_filtered = df_filtered[(log_area >= q1) & (log_area <= q3)].copy()

print(f"Retained {len(df_filtered):,} records covering area_ha "
      f"[{df_filtered['area_ha'].min():.1f} – {df_filtered['area_ha'].max():,.0f}]")
df_overview(df_filtered)
# Out:
#      column_label     type  uniques_values  non_null_values  null_values  null_value_pct
# 0        OBJECTID    int64          105296           105296            0             0.0
# 1   ignition_date   object            7791           105296            0             0.0
# 2       fire_type   object               3           105296            0             0.0
# 3         area_ha    int64               3           105296            0             0.0
# 4        perim_km    int64               7           105296            0             0.0
# 5           state   object               7           105296            0             0.0
# 6     Shape__Area  float64           74870           105296            0             0.0
# 7   Shape__Length  float64          104817           105296            0             0.0
# 8  ignition_month    int32              12           105296            0             0.0
# ...

# %%
# explore categorical features
fig, axes = plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(60, 30)
sns.violinplot(data=df_filtered,y="area_ha",orient="v",ax=axes[0][0],palette="deep")
sns.violinplot(data=df_filtered,y="area_ha",x="ignition_year",orient="v",ax=axes[0][1],palette="deep")
sns.violinplot(data=df_filtered,y="area_ha",x="ignition_month",orient="v",ax=axes[1][0],palette="deep")
sns.violinplot(data=df_filtered,y="area_ha",x="state",orient="v",ax=axes[1][1],palette="deep")
sns.color_palette("YlOrBr", as_cmap=True)



axes[0][0].set(ylabel='Area in Hectares',title="Box Plot On Area")
axes[0][1].set(xlabel='Bushfire year', ylabel='Area in Hectares',title="Box Plot On Area Across Year")
axes[1][0].set(xlabel='Bushfire month', ylabel='Area in Hectares',title="Box Plot On Area Across Month")
axes[1][1].set(xlabel='Bushfire state', ylabel='Area in Hectares',title="Box Plot On Area Across State")
# Out:
# /var/folders/n9/t0w7xncd63lg68n__n_7mc940000gq/T/ipykernel_28644/528409917.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_filtered,y="area_ha",orient="v",ax=axes[0][0],palette="deep")
# /var/folders/n9/t0w7xncd63lg68n__n_7mc940000gq/T/ipykernel_28644/528409917.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_filtered,y="area_ha",x="ignition_year",orient="v",ax=axes[0][1],palette="deep")
# /var/folders/n9/t0w7xncd63lg68n__n_7mc940000gq/T/ipykernel_28644/528409917.py:6: FutureWarning:
#
# ...

# %% [markdown]
# ### Defining dependent and independent attributes and splitting

# %%
x = df_filtered[["ignition_year", "ignition_month", "perim_km"]]
y = df_filtered["area_ha"]

# Fixed: was test_size=0.8 (80% test, only 20% train — backwards!)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)
print(f"Train: {len(x_train):,}  Test: {len(x_test):,}")

# %%
ml= LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction through manual fitting

# %%
y_pred=ml.predict(x_test)
print(y_pred)
# Out:
# [0.5139 0.1154 0.1706 ... 0.4263 0.6549 1.4006]

# %% [markdown]
# ### Total model accuracy

# %%
r2_score(y_test,y_pred)
# Out:
# 0.569357043252887

# %% [markdown]
# ##### Since our model accuracy using linear regression and manual variable fitting is less, we look for better  alternatives. We test our model with other algorithms such as elastic and xgboost targeting the area attribute.

# %% [markdown]
# ### Other algorithms

# %%
# Global variable
METRICS = ["rmse", "mae", "r2"]
N_FOLD = 10
SEED = 66
TARGET_VAR = "area_ha"

# Create dummies
df_final = df_filtered.copy()

X_interm = pd.get_dummies(df_final, columns=['state', 'ignition_date', 'fire_type'])

# %%
# Trainng data selection
X_interm_1 = X_interm[X_interm["ignition_year"] > 1980]
X_interm_1.shape

# df_filtered.drop(['datetime'], axis=1, inplace=True)
X = X_interm_1.drop(['area_ha',], axis=1).copy()

Y = X_interm_1[[TARGET_VAR]].copy()

# %% [markdown]
# ### Elastic model

# %%
# Initiate elastic net model

enet = ElasticNet(alpha=0.001, l1_ratio=0.5, max_iter=10000, random_state=SEED)

# Create model wrapper
def linear_train_and_predict(X_train_tmp, X_test_tmp, Y_train_tmp, Y_test_tmp):
    enet.fit(X_train_tmp, Y_train_tmp[TARGET_VAR])
    
    prediction_train_tmp = enet.predict(X_train_tmp)
    prediction_test_tmp = enet.predict(X_test_tmp)
    
    return prediction_train_tmp, prediction_test_tmp

df_cv_scores_elastic_net = k_fold_cv_results(linear_train_and_predict, X, Y, TARGET_VAR, n_splits=N_FOLD)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
model_result_summary(df_cv_scores_elastic_net, N_FOLD, "Elastic net model", METRICS)
# Out:
# Elastic net model for ER with 10-fold CV results in:
# Test rmse of 0.43766 with standard error of 0.00122.
# Test mae of 0.31589 with standard error of 0.00073.
# Test r2 of 0.65404 with standard error of 0.00275.

# %% [markdown]
# ### XGBoost Model

# %%
# Create an initial parameter list

params = {
    "max_depth": 13,
    "min_child_weight": 1,
    "eta": 0.2,
    "subsample": 1,
    "colsample_bytree": 1,
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "seed": SEED,
}

# Set num_boost_rounds and early stopping rounds
num_boost_rounds = 2000
early_stopping_rounds = 10

# Create model wrapper

def xgboost_train_and_predict(X_train_tmp, X_test_tmp, Y_train_tmp, Y_test_tmp):
    dtrain_tmp = xgb.DMatrix(X_train_tmp, label=Y_train_tmp[TARGET_VAR])
    dtest_tmp = xgb.DMatrix(X_test_tmp, label=Y_test_tmp[TARGET_VAR])
    
    xbg_model = xgb.train(
        params,
        dtrain_tmp,
        num_boost_round=num_boost_rounds,
        evals=[((dtest_tmp, "test"))],
        early_stopping_rounds=early_stopping_rounds,
    )
    
    prediction_train_tmp = xbg_model.predict(dtrain_tmp)
    prediction_test_tmp = xbg_model.predict(dtest_tmp)
    
    return prediction_train_tmp, prediction_test_tmp

    # Cross validation model training

df_cv_scores_xgboost = k_fold_cv_results(xgboost_train_and_predict, X, Y, TARGET_VAR, n_splits=N_FOLD)
# Out:
# [0]	test-rmse:0.59529
# [1]	test-rmse:0.47783
# [2]	test-rmse:0.38426
# [3]	test-rmse:0.30978
# [4]	test-rmse:0.25090
# [5]	test-rmse:0.20438
# [6]	test-rmse:0.16813
# [7]	test-rmse:0.13980
# [8]	test-rmse:0.11820
# [9]	test-rmse:0.10213
# [10]	test-rmse:0.09028
# [11]	test-rmse:0.08183
# [12]	test-rmse:0.07593
# [13]	test-rmse:0.07198
# [14]	test-rmse:0.06939
# [15]	test-rmse:0.06738
# [16]	test-rmse:0.06611
# [17]	test-rmse:0.06534
# [18]	test-rmse:0.06493
# [19]	test-rmse:0.06456
# [20]	test-rmse:0.06439
# [21]	test-rmse:0.06426
# [22]	test-rmse:0.06413
# [23]	test-rmse:0.06408
# [24]	test-rmse:0.06406
# [25]	test-rmse:0.06409
# [26]	test-rmse:0.06409
# [27]	test-rmse:0.06408
# [28]	test-rmse:0.06408
# [29]	test-rmse:0.06408
# [30]	test-rmse:0.06408
# [31]	test-rmse:0.06406
# [32]	test-rmse:0.06406
# [33]	test-rmse:0.06406
# [34]	test-rmse:0.06408
# [35]	test-rmse:0.06407
# [36]	test-rmse:0.06407
# [37]	test-rmse:0.06411
# [38]	test-rmse:0.06411
# [39]	test-rmse:0.06411
# ...

# %%
# Print out model result summary across 10 CVs

model_result_summary(df_cv_scores_xgboost, N_FOLD, "XGBoost model", METRICS)
# Out:
# XGBoost model for ER with 10-fold CV results in:
# Test rmse of 0.06597 with standard error of 0.00074.
# Test mae of 0.00791 with standard error of 0.00016.
# Test r2 of 0.99213 with standard error of 0.00018.

# %% [markdown]
# ### Compare model results

# %%
list_model_names = [
    "elastic_net",
    "xgboost",    
]

list_model_results = [
    df_cv_scores_elastic_net,
    df_cv_scores_xgboost
]

model_result_comparison(list_model_names, list_model_results, METRICS)
# Out:
#   modeling_approch  rmse_mean  rmse_standard_error  mae_mean  mae_standard_error   r2_mean  \
# 0      elastic_net   0.437661             0.001219  0.315886            0.000732  0.654037
# 1          xgboost   0.065972             0.000735  0.007905            0.000161  0.992132
#
#    r2_standard_error
# 0           0.002753
# 1           0.000177

# %%
# Model tuning for selected model (xgboost) using hyperopt

# Initialize domain space. The domain space is the input values over
# which we want to search.
space={
    'max_depth': hp.randint("max_depth", 3, 19),
    'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
    'eta' : hp.uniform('eta', 0.01, 0.4),
    'subsample' : hp.uniform('subsample', 0.5, 1),
    'seed': SEED
}

# Define objective function, which returns a real value that we want to minimize.
def optimize(space):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)
    dtrain_tmp = xgb.DMatrix(X_train, label=Y_train[TARGET_VAR])
    dtest_tmp = xgb.DMatrix(X_test, label=Y_test[TARGET_VAR])

    xbg_model = xgb.train(
        space,
        dtrain_tmp,
        num_boost_round=2000,
        evals=[((dtest_tmp, "test"))],
        early_stopping_rounds=10,
    )

    prediction_test = xbg_model.predict(dtest_tmp)
    mse= mean_squared_error(Y_test[TARGET_VAR], prediction_test)
    print ("SCORE:", mse)
    #change the metric if you like
    return {'loss':mse, 'status': STATUS_OK, 'model': xbg_model}

optimization = partial(optimize)

#  Optimization algorithm
trials = Trials()
best = fmin(fn=optimization,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)

print(best)
# Out:
# [0]	test-rmse:0.59836
# [1]	test-rmse:0.47795
# [2]	test-rmse:0.38258
# [3]	test-rmse:0.30743
# [4]	test-rmse:0.24801
# [5]	test-rmse:0.20178
# [6]	test-rmse:0.16584
# [7]	test-rmse:0.13833
# [8]	test-rmse:0.11747
# [9]	test-rmse:0.10221
# [10]	test-rmse:0.09124
# [11]	test-rmse:0.08324
# [12]	test-rmse:0.07777
# [13]	test-rmse:0.07397
# [14]	test-rmse:0.07154
# [15]	test-rmse:0.06991
# [16]	test-rmse:0.06908
# [17]	test-rmse:0.06851
# [18]	test-rmse:0.06807
# [19]	test-rmse:0.06780
# [20]	test-rmse:0.06765
# [21]	test-rmse:0.06755
# [22]	test-rmse:0.06750
# [23]	test-rmse:0.06744
# [24]	test-rmse:0.06743
# [25]	test-rmse:0.06741
# [26]	test-rmse:0.06740
# [27]	test-rmse:0.06744
# [28]	test-rmse:0.06742
# [29]	test-rmse:0.06744
# [30]	test-rmse:0.06744
# [31]	test-rmse:0.06745
# [32]	test-rmse:0.06741
# [33]	test-rmse:0.06742
# [34]	test-rmse:0.06742
# [35]	test-rmse:0.06743
# SCORE:
# 0.004547289982467376
# [0]	test-rmse:0.56598
# [1]	test-rmse:0.42850
# [2]	test-rmse:0.32579
# ...

# %% [markdown]
# ### Training Xgboost with winning hyperparameters
#
# To check if hyperparameter tuning has improved the model or not.

# %%
# Create an initial parameter list

params = {
    'eta': 0.17417075920759956,
    'max_depth': 17,
    'min_child_weight': 5.0,
    'subsample': 0.7078377106522445,
    "colsample_bytree": 1,
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "seed": SEED,
}

# Set num_boost_rounds and early stopping rounds
num_boost_rounds = 2000
early_stopping_rounds = 10

# Cross validation model training

df_cv_scores_xgboost = k_fold_cv_results(xgboost_train_and_predict, X, Y, TARGET_VAR, n_splits=N_FOLD)

# Print out model result summary across 10 CVs

model_result_summary(df_cv_scores_xgboost, N_FOLD, "XGBoost model", METRICS)
# Out:
# [0]	test-rmse:0.61452
# [1]	test-rmse:0.50918
# [2]	test-rmse:0.42231
# [3]	test-rmse:0.35092
# [4]	test-rmse:0.29223
# [5]	test-rmse:0.24423
# [6]	test-rmse:0.20532
# [7]	test-rmse:0.17351
# [8]	test-rmse:0.14809
# [9]	test-rmse:0.12777
# [10]	test-rmse:0.11169
# [11]	test-rmse:0.09949
# [12]	test-rmse:0.08983
# [13]	test-rmse:0.08230
# [14]	test-rmse:0.07697
# [15]	test-rmse:0.07317
# [16]	test-rmse:0.07046
# [17]	test-rmse:0.06863
# [18]	test-rmse:0.06727
# [19]	test-rmse:0.06638
# [20]	test-rmse:0.06577
# [21]	test-rmse:0.06552
# [22]	test-rmse:0.06529
# [23]	test-rmse:0.06517
# [24]	test-rmse:0.06514
# [25]	test-rmse:0.06507
# [26]	test-rmse:0.06503
# [27]	test-rmse:0.06490
# [28]	test-rmse:0.06487
# [29]	test-rmse:0.06482
# [30]	test-rmse:0.06475
# [31]	test-rmse:0.06471
# [32]	test-rmse:0.06473
# [33]	test-rmse:0.06479
# [34]	test-rmse:0.06481
# [35]	test-rmse:0.06487
# [36]	test-rmse:0.06488
# [37]	test-rmse:0.06485
# [38]	test-rmse:0.06486
# [39]	test-rmse:0.06486
# ...

# %% [markdown]
# ### Prediction leveraging xgboost

# %%
# Train the prototype model with whole dataset

params = {
    'eta': 0.17417075920759956,
    'max_depth': 17,
    'min_child_weight': 5.0,
    'subsample': 0.7078377106522445,
    "colsample_bytree": 1,
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "seed": SEED,
}

# Set num_boost_rounds and early stopping rounds
num_boost_rounds = 1000 # number of trees adjusted to avoid overfitting
early_stopping_rounds = 10


dtrain = xgb.DMatrix(X, label=Y[TARGET_VAR])

xbg_model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_rounds,
    evals=[(dtrain, "train")],
    early_stopping_rounds=early_stopping_rounds,
)
# Out:
# [0]	train-rmse:0.61572
# [1]	train-rmse:0.50976
# [2]	train-rmse:0.42235
# [3]	train-rmse:0.35037
# [4]	train-rmse:0.29107
# [5]	train-rmse:0.24233
# [6]	train-rmse:0.20227
# [7]	train-rmse:0.16938
# [8]	train-rmse:0.14257
# [9]	train-rmse:0.12062
# [10]	train-rmse:0.10281
# [11]	train-rmse:0.08841
# [12]	train-rmse:0.07691
# [13]	train-rmse:0.06770
# [14]	train-rmse:0.06036
# [15]	train-rmse:0.05451
# [16]	train-rmse:0.05017
# [17]	train-rmse:0.04661
# [18]	train-rmse:0.04393
# [19]	train-rmse:0.04180
# [20]	train-rmse:0.04015
# [21]	train-rmse:0.03914
# [22]	train-rmse:0.03837
# [23]	train-rmse:0.03752
# [24]	train-rmse:0.03673
# [25]	train-rmse:0.03643
# [26]	train-rmse:0.03601
# [27]	train-rmse:0.03571
# [28]	train-rmse:0.03555
# [29]	train-rmse:0.03532
# [30]	train-rmse:0.03516
# [31]	train-rmse:0.03493
# [32]	train-rmse:0.03479
# [33]	train-rmse:0.03463
# [34]	train-rmse:0.03452
# [35]	train-rmse:0.03444
# [36]	train-rmse:0.03442
# [37]	train-rmse:0.03430
# ...

# %%
# -------------------------------------------------------------------
# FFDI — McArthur Forest Fire Danger Index (Australian Standard)
# -------------------------------------------------------------------
# The McArthur FFDI Mark 5 is the official fire danger formula used by the
# Bureau of Meteorology and all Australian state fire services. It combines
# weather and drought conditions into a single score that maps directly onto
# BOM's fire danger ratings.  We use it here to:
#   1. Validate our XGBoost model outputs against a known ground truth
#   2. Derive range-calibrated severity scores (FFDI / 100 → 0–1)
#   3. Extract drought-factor priors by month from historical fire patterns

import math

def compute_ffdi(temperature: float, humidity: float, wind_speed: float,
                 drought_factor: float = 5.0) -> dict:
    """
    McArthur Forest Fire Danger Index — Mark 5 formula.

    FFDI = 2 · exp(−0.450 + 0.987·ln(DF) − 0.0345·H + 0.0338·T + 0.0234·V)

    Parameters
    ----------
    temperature   : float  — dry-bulb temperature in °C
    humidity      : float  — relative humidity in %
    wind_speed    : float  — 10-metre wind speed in km/h
    drought_factor: float  — Keetch-Byram drought factor, 0 (wet) – 10 (dry)

    Returns
    -------
    dict with keys: ffdi, danger_rating, severity (0-1)
    """
    df = max(0.1, min(10.0, drought_factor))
    ffdi = 2 * math.exp(
        -0.450
        + 0.987 * math.log(df)
        - 0.0345 * humidity
        + 0.0338 * temperature
        + 0.0234 * wind_speed
    )
    ffdi = max(0.0, round(ffdi, 2))

    if   ffdi < 12:  rating = "Low"
    elif ffdi < 25:  rating = "Moderate"
    elif ffdi < 50:  rating = "High"
    elif ffdi < 75:  rating = "Very High"
    elif ffdi < 100: rating = "Severe"
    else:            rating = "Extreme / Catastrophic"

    return {
        "ffdi": ffdi,
        "danger_rating": rating,
        "severity_0_to_1": round(min(ffdi / 100.0, 1.0), 4),
    }

# ----- Sanity-check against BOM documented scenarios -----
scenarios = [
    ("Mild winter day",        15, 70, 10, 1.5),
    ("Warm spring day",        25, 45, 20, 4.0),
    ("Hot dry summer",         38, 15, 50, 9.0),
    ("Black Saturday conditions", 46, 6, 89, 10.0),   # BOM FFDI was ~300
]

print(f"{'Scenario':<30} {'Temp':>5} {'Hum':>5} {'Wind':>5} {'DF':>5}  "
      f"{'FFDI':>7}  {'Rating'}")
print("-" * 80)
for name, T, H, V, DF in scenarios:
    r = compute_ffdi(T, H, V, DF)
    print(f"{name:<30} {T:>5}°C {H:>4}%  {V:>4}km/h DF={DF}  "
          f"FFDI={r['ffdi']:>7.1f}  {r['danger_rating']}")

# %%
# ------------------------------------------------------------------
# Seasonal drought factor priors from historical fire data
# ------------------------------------------------------------------
# Fire frequency peaks in the months when drought factor is highest.
# We use the historical boundaries dataset to derive per-month "relative
# drought" priors that feed into engine.ts MONTHLY_DROUGHT_FACTOR.

monthly_stats = (
    df_filtered.groupby("ignition_month")
    .agg(
        fire_count=("area_ha", "count"),
        avg_area=("area_ha", "mean"),
        max_area=("area_ha", "max"),
    )
    .reset_index()
)

# Normalise fire count → proxy for drought factor (scale 1.5–10)
cnt_min = monthly_stats["fire_count"].min()
cnt_max = monthly_stats["fire_count"].max()
monthly_stats["df_prior"] = (
    1.5 + 8.5 * (monthly_stats["fire_count"] - cnt_min) / (cnt_max - cnt_min)
).round(1)

print("Monthly drought-factor priors (derived from historical fire frequency):\n")
print(f"{'Month':>6}  {'Fire count':>12}  {'Avg area (ha)':>14}  {'DF prior':>10}")
print("-" * 50)
for _, row in monthly_stats.iterrows():
    print(f"{int(row.ignition_month):>6}  {int(row.fire_count):>12,}  "
          f"{row.avg_area:>14.1f}  {row.df_prior:>10.1f}")

engine_monthly_df = dict(zip(monthly_stats["ignition_month"].astype(int),
                              monthly_stats["df_prior"]))
print(f"\nengine.ts MONTHLY_DROUGHT_FACTOR = {engine_monthly_df}")

fig, ax1 = plt.subplots(figsize=(10, 4))
ax1.bar(monthly_stats["ignition_month"], monthly_stats["fire_count"] / 1000,
        color="firebrick", alpha=0.7, label="Fire count (×1000)")
ax2 = ax1.twinx()
ax2.plot(monthly_stats["ignition_month"], monthly_stats["df_prior"],
         "o-", color="darkorange", lw=2, label="DF prior")
ax1.set_xlabel("Month"); ax1.set_ylabel("Fire count (×1000)", color="firebrick")
ax2.set_ylabel("Drought Factor prior", color="darkorange")
ax1.set_title("Historical fire frequency → drought-factor priors by month")
fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))
plt.tight_layout(); plt.show()

# %%
# ------------------------------------------------------------------
# Feature importance from the trained XGBoost model
# ------------------------------------------------------------------
scores = xbg_model.get_score(importance_type="gain")

fi_df = (
    pd.DataFrame(list(scores.items()), columns=["feature", "gain"])
    .sort_values("gain", ascending=False)
    .reset_index(drop=True)
)
fi_df["gain_pct"] = (fi_df["gain"] / fi_df["gain"].sum() * 100).round(2)
print(fi_df.head(20).to_string(index=False))

fig, ax = plt.subplots(figsize=(10, min(0.4 * len(fi_df), 12)))
ax.barh(fi_df["feature"][:20][::-1], fi_df["gain_pct"][:20][::-1], color="steelblue")
ax.set_xlabel("Importance (% gain)")
ax.set_title("XGBoost feature importance — top 20 features")
plt.tight_layout(); plt.show()

# %%
# ------------------------------------------------------------------
# Export model + engine.ts calibration artefacts
# ------------------------------------------------------------------
import json, os

# 1. Save XGBoost model (can be loaded by a Python sidecar service)
xbg_model.save_model("xgb_bushfire.json")
print("Saved: xgb_bushfire.json")

# 2. Export FFDI-calibrated engine weights as JSON
#    These match MONTHLY_DROUGHT_FACTOR in engine.ts
engine_weights = {
    "version": "1.0",
    "source": "historic_bushfire.ipynb",
    "description": (
        "Monthly drought-factor priors derived from Geoscience Australia "
        "Historical Bushfire Boundaries Dataset. Used by engine.ts when "
        "no real-time drought factor is available."
    ),
    "monthly_drought_factor": engine_monthly_df,
    "ffdi_normalization": {
        "divide_by": 100,
        "cap_at": 1.0,
        "rationale": "FFDI 100 = severity 1.0; catastrophic fires exceed 100",
    },
    "danger_ratings": {
        "Low": [0, 11], "Moderate": [12, 24], "High": [25, 49],
        "Very High": [50, 74], "Severe": [75, 99], "Extreme": [100, 999],
    },
}
weights_path = "../server/prediction-service/engine-weights.json"
os.makedirs(os.path.dirname(weights_path), exist_ok=True)
with open(weights_path, "w") as f:
    json.dump(engine_weights, f, indent=2)

print(f"Saved: {weights_path}")
print(json.dumps(engine_weights, indent=2))

# %%
## Agentic Risk Assessment with Ollama (nous-hermes2)

Rather than a static lookup, we can give a locally-running LLM three grounded tools:

| Tool | Data source | What it does |
|---|---|---|
| `compute_ffdi` | McArthur formula | Computes the official AUS fire danger score |
| `fetch_weather` | **Open-Meteo** (free, no key) | Pulls real-time weather + soil moisture |
| `get_historical_risk` | Our training CSV | Returns historical fire frequency for a state/month |

The agent uses a **ReAct** loop (Reason → Act → Observe → repeat) to answer a risk query. Since `nous-hermes2` supports Hermes function-call formatting, we instruct it to return a JSON action object and dispatch it ourselves. This keeps execution deterministic and auditable — critical for safety-of-life systems.

Open-Meteo provides soil moisture data which we convert to a drought factor approximation: `DF ≈ 10 × (1 − soil_moisture / 0.4)`.  No API key required; latency is ~200 ms.

# %%
import requests
import json
import re

# ── Tool implementations ──────────────────────────────────────────────────────

def tool_compute_ffdi(temperature: float, humidity: float, wind_speed: float,
                      drought_factor: float = 5.0) -> dict:
    """Wraps compute_ffdi defined above."""
    return compute_ffdi(temperature, humidity, wind_speed, drought_factor)


def tool_fetch_weather(latitude: float, longitude: float) -> dict:
    """
    Real-time weather from Open-Meteo — free, no API key.
    Returns temperature (°C), humidity (%), wind speed (km/h), and a
    drought-factor approximation derived from surface soil moisture.
    """
    url = (
        "https://api.open-meteo.com/v1/forecast"
        f"?latitude={latitude}&longitude={longitude}"
        "&current=temperature_2m,relative_humidity_2m,wind_speed_10m,"
        "soil_moisture_0_to_1cm,wind_direction_10m"
        "&wind_speed_unit=kmh&timezone=auto"
    )
    try:
        resp = requests.get(url, timeout=8)
        resp.raise_for_status()
        curr = resp.json()["current"]
        soil = max(curr.get("soil_moisture_0_to_1cm", 0.15), 0.001)
        df_approx = round(10 * max(0, 1 - soil / 0.4), 1)   # 0=saturated, 10=bone dry
        deg = curr.get("wind_direction_10m", 0)
        dirs = ["N","NE","E","SE","S","SW","W","NW"]
        wind_dir = dirs[int((deg + 22.5) // 45) % 8]
        return {
            "temperature":     curr["temperature_2m"],
            "humidity":        curr["relative_humidity_2m"],
            "wind_speed_kmh":  curr["wind_speed_10m"],
            "wind_direction":  wind_dir,
            "soil_moisture":   round(soil, 3),
            "drought_factor":  df_approx,
        }
    except Exception as exc:
        return {"error": str(exc)}


def tool_get_historical_risk(state: str, month: int) -> dict:
    """Historical fire frequency for an Australian state/month from our CSV."""
    s = state.upper().strip()
    mask = (df_filtered["state"] == s) & (df_filtered["ignition_month"] == month)
    month_total = int((df_filtered["ignition_month"] == month).sum())
    count = int(mask.sum())
    avg_area = float(df_filtered.loc[mask, "area_ha"].mean()) if count > 0 else 0.0
    return {
        "state": s,
        "month": month,
        "fire_count_in_dataset": count,
        "state_share_pct": round(count / month_total * 100, 1) if month_total else 0,
        "avg_area_ha": round(avg_area, 1),
        "note": "Source: Geoscience Australia Historical Bushfire Boundaries v2",
    }


TOOLS_DISPATCH = {
    "compute_ffdi":       tool_compute_ffdi,
    "fetch_weather":      tool_fetch_weather,
    "get_historical_risk": tool_get_historical_risk,
}

TOOL_SCHEMAS = [
    {
        "name": "compute_ffdi",
        "description": "Compute the McArthur Mark 5 FFDI (official Australian fire danger index).",
        "parameters": {
            "temperature":    "float, °C",
            "humidity":       "float, %RH",
            "wind_speed":     "float, km/h",
            "drought_factor": "float 0–10 (default 5)",
        },
    },
    {
        "name": "fetch_weather",
        "description": (
            "Fetch LIVE weather from Open-Meteo (free, no key). "
            "Returns temperature, humidity, wind speed, wind direction, "
            "soil moisture, and an estimated drought factor."
        ),
        "parameters": {"latitude": "float", "longitude": "float"},
    },
    {
        "name": "get_historical_risk",
        "description": (
            "Look up historical fire frequency for a state+month from the "
            "Geoscience Australia bushfire boundaries dataset."
        ),
        "parameters": {
            "state": "AUS state code — NSW/VIC/SA/WA/QLD/TAS/ACT",
            "month": "int 1–12",
        },
    },
]

print("Tools registered:", list(TOOLS_DISPATCH.keys()))
print("Open-Meteo test (Sydney):", tool_fetch_weather(-33.87, 151.21))

# %%
# ── ReAct agent loop ─────────────────────────────────────────────────────────
# Ollama is already running locally (docker-compose). The agent is given a
# system prompt explaining the ReAct contract, then iterates: it emits a JSON
# action → we execute the tool → we feed the result back as a user message.

OLLAMA_URL    = "http://localhost:11434/v1/chat/completions"
OLLAMA_MODEL  = "nous-hermes2"

SYSTEM_PROMPT = (
    "You are a bushfire risk assessment agent for Project Haven, an Australian "
    "emergency response platform.\n\n"
    "You MUST use the provided tools to gather data before answering. "
    "Respond ONLY with valid JSON — no prose, no markdown fences.\n\n"
    "To call a tool, output exactly:\n"
    '{"thought":"<your reasoning>","action":"<tool_name>","args":{<args>}}\n\n'
    "When you have enough information to write a final answer, output exactly:\n"
    '{"thought":"<reasoning>","final_answer":"<comprehensive plain-text assessment>"}\n\n'
    "Available tools:\n"
    + json.dumps(TOOL_SCHEMAS, indent=2)
)


def run_fire_risk_agent(query: str, max_steps: int = 8, verbose: bool = True) -> str:
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": query},
    ]

    for step in range(1, max_steps + 1):
        resp = requests.post(
            OLLAMA_URL,
            json={
                "model": OLLAMA_MODEL,
                "messages": messages,
                "temperature": 0.05,
                "max_tokens": 600,
            },
            timeout=90,
        )
        resp.raise_for_status()

        content = resp.json()["choices"][0]["message"]["content"].strip()
        messages.append({"role": "assistant", "content": content})

        # Strip markdown fences if the model wraps its JSON
        raw = re.sub(r"^```(?:json)?\s*|\s*```$", "", content.strip())
        # Extract first JSON object
        match = re.search(r"\{.*\}", raw, re.DOTALL)
        if not match:
            if verbose:
                print(f"[Step {step}] Non-JSON response, treating as final:\n{content}")
            return content

        try:
            parsed = json.loads(match.group())
        except json.JSONDecodeError:
            if verbose:
                print(f"[Step {step}] JSON parse error:\n{content}")
            return content

        if "final_answer" in parsed:
            if verbose:
                print(f"\n[Agent] Thought: {parsed.get('thought','')}")
            return parsed["final_answer"]

        # It's a tool call
        tool_name = parsed.get("action", "")
        args      = parsed.get("args", {})
        thought   = parsed.get("thought", "")

        if verbose:
            print(f"[Step {step}] Thought : {thought}")
            print(f"[Step {step}] Calling : {tool_name}({args})")

        if tool_name in TOOLS_DISPATCH:
            try:
                result = TOOLS_DISPATCH[tool_name](**args)
            except Exception as exc:
                result = {"error": str(exc)}
        else:
            result = {"error": f"Unknown tool '{tool_name}'"}

        if verbose:
            print(f"[Step {step}] Result  : {result}\n")

        messages.append({"role": "user", "content": f"Tool result: {json.dumps(result)}"})

    return "Agent reached max steps without a final answer."

# %%
# ── Example queries ──────────────────────────────────────────────────────────
# Run these after Ollama is up (`docker compose up` in the project root).
# Ollama serves nous-hermes2 at http://localhost:11434.

queries = [
    # Lat/lon for Greater Sydney
    "Assess the current bushfire risk near Sydney, NSW (lat -33.87, lon 151.21). "
    "Use current weather conditions and historical patterns for this time of year.",

    # Lat/lon for Melbourne CBD
    "What is the fire danger level near Melbourne, VIC (lat -37.81, lon 144.96) right now? "
    "Include an FFDI score and advise on evacuation readiness.",
]

for q in queries:
    print("=" * 72)
    print(f"QUERY: {q}\n")
    answer = run_fire_risk_agent(q, verbose=True)
    print(f"\n{'─'*72}")
    print("ASSESSMENT:")
    print(answer)
    print("=" * 72, "\n")
